# %%
from bs4 import BeautifulSoup
from ipynb.fs.full.racing_tv_functions import *

import datetime
import json
import numpy as np
import pandas as pd
import re
import requests
import time

# %%
update_race_data(delay = 0.1)
# Out:
# Collecting data for 2025-08-31
# Worcester
# Collected race data for Worcester at 14:10
# Collected race data for Worcester at 14:40
# Collected race data for Worcester at 15:10
# Collected race data for Worcester at 15:40
# Collected race data for Worcester at 16:10
# Collected race data for Worcester at 16:40
# Collected race data for Worcester at 17:10
# Collected race data for Worcester at 17:40
# Progress: 1/3
# Tipperary
# Collected race data for Tipperary at 14:30
# Collected race data for Tipperary at 15:00
# Collected race data for Tipperary at 15:30
# Collected race data for Tipperary at 16:00
# Collected race data for Tipperary at 16:30
# Collected race data for Tipperary at 17:00
# Collected race data for Tipperary at 17:30
# Progress: 2/3
# Brighton
# Collected race data for Brighton at 13:52
# Collected race data for Brighton at 14:22
# Collected race data for Brighton at 14:52
# Collected race data for Brighton at 15:22
# Collected race data for Brighton at 15:52
# Collected race data for Brighton at 16:22
# Collected race data for Brighton at 16:52
# Could not find "horses" in the json
# Collected race data for Brighton at 17:22
# Progress: 3/3
# Collecting data for 2025-09-01
# Windsor
# Collected race data for Windsor at 16:30
# Collected race data for Windsor at 17:00
# Collected race data for Windsor at 17:30
# Collected race data for Windsor at 18:00
# Collected race data for Windsor at 18:30
# Collected race data for Windsor at 19:00
# Collected race data for Windsor at 19:30
# Progress: 1/4
# Carlisle
# Collected race data for Carlisle at 14:00
# Collected race data for Carlisle at 14:30
# Collected race data for Carlisle at 15:00
# Collected race data for Carlisle at 15:30
# Collected race data for Carlisle at 16:05
# Collected race data for Carlisle at 16:37
# Collected race data for Carlisle at 17:07
# Collected race data for Carlisle at 17:37
# Progress: 2/4
# Roscommon
# Collected race data for Roscommon at 16:12
# Collected race data for Roscommon at 16:45
# Collected race data for Roscommon at 17:15
# Collected race data for Roscommon at 17:45
# Collected race data for Roscommon at 18:15
# Collected race data for Roscommon at 18:45
# Collected race data for Roscommon at 19:15
# Progress: 3/4
# Brighton
# Collected race data for Brighton at 14:15
# Collected race data for Brighton at 14:45
# Collected race data for Brighton at 15:15
# Collected race data for Brighton at 15:50
# Collected race data for Brighton at 16:20
# Collected race data for Brighton at 16:52
# Collected race data for Brighton at 17:22
# Progress: 4/4
# Collecting data for 2025-09-02
# Wolverhampton
# Collected race data for Wolverhampton at 17:10
# Collected race data for Wolverhampton at 17:45
# Collected race data for Wolverhampton at 18:15
# Collected race data for Wolverhampton at 18:45
# Collected race data for Wolverhampton at 19:15
# Collected race data for Wolverhampton at 19:45
# Collected race data for Wolverhampton at 20:15
# Collected race data for Wolverhampton at 20:45
# Progress: 1/5
# Goodwood
# Collected race data for Goodwood at 13:48
# Collected race data for Goodwood at 14:23
# Collected race data for Goodwood at 14:58
# Collected race data for Goodwood at 15:33
# Collected race data for Goodwood at 16:08
# Collected race data for Goodwood at 16:43
# Collected race data for Goodwood at 17:18
# Progress: 2/5
# Southwell
# Collected race data for Southwell at 17:30
# Collected race data for Southwell at 18:00
# Collected race data for Southwell at 18:30
# Collected race data for Southwell at 19:00
# Collected race data for Southwell at 19:30
# Collected race data for Southwell at 20:00
# Collected race data for Southwell at 20:30
# Collected race data for Southwell at 21:00
# Progress: 3/5
# Chepstow
# Collected race data for Chepstow at 14:00
# Collected race data for Chepstow at 14:35
# Collected race data for Chepstow at 15:10
# Collected race data for Chepstow at 15:45
# Collected race data for Chepstow at 16:20
# Collected race data for Chepstow at 16:55
# Collected race data for Chepstow at 17:25
# Progress: 4/5
# Gowran-Park
# Collected race data for Gowran-Park at 13:35
# Collected race data for Gowran-Park at 14:10
# Collected race data for Gowran-Park at 14:45
# Collected race data for Gowran-Park at 15:20
# Collected race data for Gowran-Park at 15:55
# Collected race data for Gowran-Park at 16:30
# Collected race data for Gowran-Park at 17:02
# Collected race data for Gowran-Park at 17:37
# Progress: 5/5
# Collecting data for 2025-09-03
# Bath
# Collected race data for Bath at 14:20
# Collected race data for Bath at 14:50
# Collected race data for Bath at 15:20
# Collected race data for Bath at 15:50
# Collected race data for Bath at 16:20
# Collected race data for Bath at 16:50
# Collected race data for Bath at 17:25
# Progress: 1/4
# Hamilton-Park
# Collected race data for Hamilton-Park at 16:13
# Collected race data for Hamilton-Park at 16:45
# Collected race data for Hamilton-Park at 17:15
# Collected race data for Hamilton-Park at 17:45
# Collected race data for Hamilton-Park at 18:15
# Collected race data for Hamilton-Park at 18:45
# Collected race data for Hamilton-Park at 19:15
# Collected race data for Hamilton-Park at 19:45
# Progress: 2/4
# Kempton-Park
# Collected race data for Kempton-Park at 18:00
# Collected race data for Kempton-Park at 18:30
# Collected race data for Kempton-Park at 19:00
# Collected race data for Kempton-Park at 19:30
# Collected race data for Kempton-Park at 20:00
# Collected race data for Kempton-Park at 20:30
# Collected race data for Kempton-Park at 21:00
# Progress: 3/4
# Lingfield-Park
# Collected race data for Lingfield-Park at 13:35
# Collected race data for Lingfield-Park at 14:05
# Collected race data for Lingfield-Park at 14:35
# Collected race data for Lingfield-Park at 15:05
# Collected race data for Lingfield-Park at 15:35
# Collected race data for Lingfield-Park at 16:05
# Collected race data for Lingfield-Park at 16:35
# Collected race data for Lingfield-Park at 17:05
# Collected race data for Lingfield-Park at 17:35
# Progress: 4/4
# Collecting data for 2025-09-04
# Sedgefield
# Collected race data for Sedgefield at 16:53
# Collected race data for Sedgefield at 17:28
# Collected race data for Sedgefield at 18:00
# Collected race data for Sedgefield at 18:30
# Collected race data for Sedgefield at 19:00
# Collected race data for Sedgefield at 19:30
# Progress: 1/6
# Lingfield-Park
# Collected race data for Lingfield-Park at 15:40
# Collected race data for Lingfield-Park at 16:10
# Collected race data for Lingfield-Park at 16:43
# Collected race data for Lingfield-Park at 17:18
# Collected race data for Lingfield-Park at 17:50
# Collected race data for Lingfield-Park at 18:20
# Collected race data for Lingfield-Park at 18:50
# Collected race data for Lingfield-Park at 19:20
# Progress: 2/6
# Southwell
# Collected race data for Southwell at 13:50
# Collected race data for Southwell at 14:20
# Collected race data for Southwell at 14:50
# Collected race data for Southwell at 15:20
# Collected race data for Southwell at 15:55
# Collected race data for Southwell at 16:25
# Collected race data for Southwell at 17:00
# Collected race data for Southwell at 17:35
# Progress: 3/6
# Laytown
# Collected race data for Laytown at 16:30
# Collected race data for Laytown at 17:05
# Collected race data for Laytown at 17:40
# Collected race data for Laytown at 18:10
# Collected race data for Laytown at 18:40
# Collected race data for Laytown at 19:10
# Progress: 4/6
# Haydock-Park
# Collected race data for Haydock-Park at 14:00
# Collected race data for Haydock-Park at 14:30
# Collected race data for Haydock-Park at 15:00
# Collected race data for Haydock-Park at 15:30
# Collected race data for Haydock-Park at 16:02
# Collected race data for Haydock-Park at 16:37
# Collected race data for Haydock-Park at 17:12
# Progress: 5/6
# Salisbury
# Collected race data for Salisbury at 14:10
# Collected race data for Salisbury at 14:40
# Collected race data for Salisbury at 15:10
# Collected race data for Salisbury at 15:47
# Collected race data for Salisbury at 16:18
# Collected race data for Salisbury at 16:48
# Collected race data for Salisbury at 17:23
# Progress: 6/6
# Collecting data for 2025-09-05
# Kempton-Park
# Collected race data for Kempton-Park at 17:47
# Collected race data for Kempton-Park at 18:17
# Collected race data for Kempton-Park at 18:47
# Collected race data for Kempton-Park at 19:17
# Collected race data for Kempton-Park at 19:47
# Collected race data for Kempton-Park at 20:17
# Collected race data for Kempton-Park at 20:47
# Progress: 1/7
# Down-Royal
# Collected race data for Down-Royal at 16:15
# Collected race data for Down-Royal at 16:50
# Collected race data for Down-Royal at 17:22
# Collected race data for Down-Royal at 17:54
# Collected race data for Down-Royal at 18:24
# Collected race data for Down-Royal at 18:54
# Collected race data for Down-Royal at 19:24
# Progress: 2/7
# Kilbeggan
# Collected race data for Kilbeggan at 15:57
# Collected race data for Kilbeggan at 16:32
# Collected race data for Kilbeggan at 17:07
# Collected race data for Kilbeggan at 17:37
# Collected race data for Kilbeggan at 18:07
# Collected race data for Kilbeggan at 18:37
# Collected race data for Kilbeggan at 19:07
# Progress: 3/7
# Worcester
# Collected race data for Worcester at 16:25
# Collected race data for Worcester at 17:00
# Collected race data for Worcester at 17:30
# Collected race data for Worcester at 18:00
# Collected race data for Worcester at 18:30
# Collected race data for Worcester at 19:00
# Collected race data for Worcester at 19:30
# Progress: 4/7
# Ascot
# Collected race data for Ascot at 13:45
# Collected race data for Ascot at 14:20
# Collected race data for Ascot at 14:55
# Collected race data for Ascot at 15:30
# Collected race data for Ascot at 16:05
# Collected race data for Ascot at 16:40
# Collected race data for Ascot at 17:15
# Progress: 5/7
# Bangor-On-Dee
# Collected race data for Bangor-On-Dee at 13:55
# Collected race data for Bangor-On-Dee at 14:30
# Collected race data for Bangor-On-Dee at 15:05
# Collected race data for Bangor-On-Dee at 15:40
# Collected race data for Bangor-On-Dee at 16:10
# Collected race data for Bangor-On-Dee at 16:45
# Progress: 6/7
# Haydock-Park
# Collected race data for Haydock-Park at 13:32
# Collected race data for Haydock-Park at 14:07
# Collected race data for Haydock-Park at 14:42
# Collected race data for Haydock-Park at 15:15
# Collected race data for Haydock-Park at 15:50
# Collected race data for Haydock-Park at 16:20
# Collected race data for Haydock-Park at 16:55
# Collected race data for Haydock-Park at 17:27
# Progress: 7/7
# Collecting data for 2025-09-06
# Ascot
# Collected race data for Ascot at 13:40
# Collected race data for Ascot at 14:10
# Collected race data for Ascot at 14:40
# Collected race data for Ascot at 15:15
# Collected race data for Ascot at 15:50
# Collected race data for Ascot at 16:25
# Collected race data for Ascot at 16:55
# Progress: 1/7
# Haydock-Park
# Collected race data for Haydock-Park at 13:15
# Collected race data for Haydock-Park at 13:50
# Collected race data for Haydock-Park at 14:25
# Collected race data for Haydock-Park at 15:00
# Collected race data for Haydock-Park at 15:35
# Collected race data for Haydock-Park at 16:07
# Collected race data for Haydock-Park at 16:40
# Collected race data for Haydock-Park at 17:15
# Progress: 2/7
# Kempton-Park
# Collected race data for Kempton-Park at 13:35
# Collected race data for Kempton-Park at 14:05
# Collected race data for Kempton-Park at 14:35
# Collected race data for Kempton-Park at 15:10
# Collected race data for Kempton-Park at 15:45
# Collected race data for Kempton-Park at 16:20
# Collected race data for Kempton-Park at 16:50
# Progress: 3/7
# Stratford-on-Avon
# Collected race data for Stratford-on-Avon at 16:12
# Collected race data for Stratford-on-Avon at 16:45
# Collected race data for Stratford-on-Avon at 17:22
# Collected race data for Stratford-on-Avon at 17:55
# Collected race data for Stratford-on-Avon at 18:25
# Collected race data for Stratford-on-Avon at 18:55
# Progress: 4/7
# Thirsk
# Collected race data for Thirsk at 14:20
# Collected race data for Thirsk at 14:50
# Collected race data for Thirsk at 15:25
# Collected race data for Thirsk at 16:00
# Collected race data for Thirsk at 16:35
# Collected race data for Thirsk at 17:05
# Collected race data for Thirsk at 17:35
# Progress: 5/7
# Wolverhampton
# Collected race data for Wolverhampton at 17:10
# Collected race data for Wolverhampton at 17:40
# Collected race data for Wolverhampton at 18:12
# Collected race data for Wolverhampton at 18:42
# Collected race data for Wolverhampton at 19:12
# Collected race data for Wolverhampton at 19:42
# Collected race data for Wolverhampton at 20:12
# Collected race data for Wolverhampton at 20:42
# Progress: 6/7
# Navan
# Collected race data for Navan at 13:45
# Collected race data for Navan at 14:15
# Collected race data for Navan at 14:45
# Collected race data for Navan at 15:20
# Collected race data for Navan at 15:55
# Collected race data for Navan at 16:30
# Collected race data for Navan at 17:00
# Collected race data for Navan at 17:30
# Progress: 7/7
# Collecting data for 2025-09-07
# Fontwell-Park
# Collected race data for Fontwell-Park at 14:12
# Collected race data for Fontwell-Park at 14:42
# Collected race data for Fontwell-Park at 15:12
# Collected race data for Fontwell-Park at 15:42
# Collected race data for Fontwell-Park at 16:12
# Collected race data for Fontwell-Park at 16:42
# Progress: 1/2
# York
# Collected race data for York at 14:30
# Collected race data for York at 15:00
# Collected race data for York at 15:30
# Collected race data for York at 16:00
# Collected race data for York at 16:30
# Collected race data for York at 17:00
# Collected race data for York at 17:30
# Progress: 2/2
# Data saved to: historical_horse_data.json
# 'The historical race data and race times were successfully updated.'

# %%
today_races = todays_data_df(delay = 0.1)
# Out:
# Collected race data for Newton Abbot at 13:58
# Collected race data for Newton Abbot at 14:28
# Collected race data for Newton Abbot at 14:58
# Collected race data for Newton Abbot at 15:28
# Collected race data for Newton Abbot at 15:58
# Collected race data for Newton Abbot at 16:30
# Collected race data for Newton Abbot at 17:00
# Collected race data for Leicester at 14:20
# Collected race data for Leicester at 14:50
# Collected race data for Leicester at 15:20
# Collected race data for Leicester at 15:50
# Collected race data for Leicester at 16:25
# Collected race data for Leicester at 16:55
# Collected race data for Leicester at 17:25
# Collected race data for Catterick at 14:10
# Collected race data for Catterick at 14:40
# Collected race data for Catterick at 15:10
# Collected race data for Catterick at 15:40
# Collected race data for Catterick at 16:10
# Collected race data for Catterick at 16:40
# Collected race data for Catterick at 17:10
# Collected race data for Galway at 16:05
# Collected race data for Galway at 16:35
# Collected race data for Galway at 17:05
# Collected race data for Galway at 17:35
# Collected race data for Galway at 18:05
# Collected race data for Galway at 18:35
# Collected race data for Galway at 19:05
# Collected race data for Galway at 19:35
# Collected race data for Ffos Las at 16:20
# Collected race data for Ffos Las at 16:50
# Collected race data for Ffos Las at 17:20
# Collected race data for Ffos Las at 17:55
# Collected race data for Ffos Las at 18:25
# Collected race data for Ffos Las at 18:55
# Collected race data for Ffos Las at 19:25
# Collected race data for Carlisle at 16:15
# Collected race data for Carlisle at 16:45
# Collected race data for Carlisle at 17:15
# Collected race data for Carlisle at 17:45
# Collected race data for Carlisle at 18:15
# Collected race data for Carlisle at 18:45
# Collected race data for Carlisle at 19:15

# %%
horse_df = unpack_json_to_df('historical_horse_data.json')

# %%
cleaned_df = horse_df.dropna(subset=['Position'])
cleaned_df = cleaned_df.replace('N/A', np.nan)
cleaned_df[['Finishing Speed (%)', 'Top Speed Value (mph)']] = cleaned_df[['Finishing Speed (%)', 'Top Speed Value (mph)']].astype(float)

# %%
conditions = {}
id_list = cleaned_df['Race Id'].unique().tolist()
for race_id in id_list:
    conditions.update({race_id : finish_condition(cleaned_df, race_id)})

# %%
high_condition_dict, med_condition_dict, low_condition_dict = ({} for i in range(3))

for race_id in conditions.keys():
    condition_list = conditions[race_id]
    # Update dictionary with {race_id, mean + std}
    high_condition_dict.update({race_id : condition_list[0] + condition_list[1]})
    # Update dictionary with {race_id, mean + 0.8 * std}
    med_condition_dict.update({race_id : condition_list[0] + 0.8 * condition_list[1]})
    # Update dictionary with {race_id, mean + 0.5 * std}
    low_condition_dict.update({race_id : condition_list[0] + 0.5 * condition_list[1]})

# %%
high_fast_list = []
speed_list = cleaned_df['Finishing Speed (%)'].tolist()
id_list = cleaned_df['Race Id'].tolist()

for i in range(len(speed_list)):
    condition = speed_list[i] >= high_condition_dict[id_list[i]]
    if condition:
        high_fast_list.append(True)
    else:
        high_fast_list.append(np.nan)

# %%
med_fast_list = []

for i in range(len(speed_list)):
    condition = speed_list[i] >= med_condition_dict[id_list[i]]
    if condition:
        med_fast_list.append(True)
    else:
        med_fast_list.append(np.nan)

# %%
low_fast_list = []

for i in range(len(speed_list)):
    condition = speed_list[i] >= low_condition_dict[id_list[i]]
    if condition:
        low_fast_list.append(True)
    else:
        low_fast_list.append(np.nan)

# %%
cleaned_df.insert(0, 'Low Fast Finish' , low_fast_list)
cleaned_df.insert(0, 'Med Fast Finish' , med_fast_list)
cleaned_df.insert(0, 'High Fast Finish' , high_fast_list)

# %%
cleaned_df['Fast Finish'] = np.where((cleaned_df['High Fast Finish'] == True) & (cleaned_df['Position'] == 1), True, False)

# %%
grouped_df = cleaned_df.groupby([cleaned_df['Horse']]).agg(
    **{
        # 'Best Finish (%)' : pd.NamedAgg(column = 'Finishing Speed (%)', aggfunc = 'max'),
        # 'Mean Finish (%)' : pd.NamedAgg(column = 'Finishing Speed (%)', aggfunc = 'mean'),
        # 'Worst Finish (%)' : pd.NamedAgg(column = 'Finishing Speed (%)', aggfunc = 'min'),
        # 'Std Finish (%)' : pd.NamedAgg(column = 'Finishing Speed (%)', aggfunc = 'std'),
        # 'Median Finish (%)' : pd.NamedAgg(column = 'Finishing Speed (%)', aggfunc = 'median'),
        'Best Speed (mph)' : pd.NamedAgg(column = 'Top Speed Value (mph)', aggfunc = 'max'),
        'Best Pos' : pd.NamedAgg(column = 'Position', aggfunc = 'min'),
        'Mean Pos' : pd.NamedAgg(column = 'Position', aggfunc = 'mean'),
        'Worst Pos' : pd.NamedAgg(column = 'Position', aggfunc = 'max'),
        'Std Pos' : pd.NamedAgg(column = 'Position', aggfunc = 'std'),
        'High Fast Finishes' : pd.NamedAgg(column = 'High Fast Finish', aggfunc = 'count'),
        'Med Fast Finishes' : pd.NamedAgg(column = 'Med Fast Finish', aggfunc = 'count'),
        'Low Fast Finishes' : pd.NamedAgg(column = 'Low Fast Finish', aggfunc = 'count'),
        'Num Wins' : pd.NamedAgg(column = 'Position', aggfunc = lambda x : (x == 1).sum()),
        'Num Podiums' : pd.NamedAgg(column = 'Position', aggfunc = lambda x : (x <= 3).sum()),
        'Num Fast Wins' : pd.NamedAgg(column = 'Fast Finish', aggfunc = lambda x : (x == True).sum()),
        'Num Races' : pd.NamedAgg(column = 'Position', aggfunc = 'count'), # Number of non-null position values (we have removed all null values)
    }
)

grouped_df['High Fast Races (%)'] = grouped_df['High Fast Finishes'] / grouped_df['Num Races']
grouped_df['Med Fast Races (%)'] = grouped_df['Med Fast Finishes'] / grouped_df['Num Races']
grouped_df['Low Fast Races (%)'] = grouped_df['Low Fast Finishes'] / grouped_df['Num Races']

# %%
grouped_df = grouped_df[['High Fast Races (%)', 'Med Fast Races (%)', 'Low Fast Races (%)', 'Best Speed (mph)',
                         'Best Pos', 'Mean Pos', 'Worst Pos', 'Std Pos', 'High Fast Finishes', 'Med Fast Finishes',
                         'Low Fast Finishes', 'Num Wins', 'Num Podiums', 'Num Fast Wins', 'Num Races']].reset_index()

# %%
today_races = today_races[['Off Time', 'Track', 'Tips']].reset_index()

# Some horse names have different cases on racingtv and racingpost.
# Merging on 'Horse' without case sensitivity.
today_races = pd.merge(
    today_races,
    grouped_df,

    # Used to make merge non case sensitive.
    left_on = today_races['Horse'].str.lower(),
    right_on = grouped_df['Horse'].str.lower(),
                       
    how = 'inner',

    # Used so we can easily remove duplicated 'Horse' column later.
    suffixes = ('', '_y')
)

# Dropping unwanted columns generated during the merge.
today_races = today_races.drop(columns = ['key_0', 'Horse_y']).set_index('Off Time')

today_races = today_races.reset_index().set_index('Off Time')
today_races = today_races[['Track', 'Horse', 'High Fast Races (%)', 'Med Fast Races (%)', 'Low Fast Races (%)',
                           'Best Speed (mph)', 'Best Pos', 'Mean Pos', 'Worst Pos', 'Std Pos', 'Num Wins',
#                           'High Fast Finishes', 'Med Fast Finishes', 'Low Fast Finishes',
                           'Num Podiums', 'Num Fast Wins', 'Num Races', 'Tips']]

# %%
todays_date = pd.Timestamp.today().strftime('%d-%m-%Y')
today_races.round(2).to_csv('./Horse Data/horse_data_{:s}.csv'.format(todays_date))

# %%
today_races
# Out:
#                  Track            Horse  High Fast Races (%)  \
# Off Time
# 13:58     Newton Abbot             Lord             0.500000
# 13:58     Newton Abbot          Mancero             0.000000
# 13:58     Newton Abbot            Genbu             0.000000
# 13:58     Newton Abbot     Manyana Blue             0.000000
# 13:58     Newton Abbot        Pistrucci             0.000000
# ...                ...              ...                  ...
# 19:15         Carlisle           Bowood             0.200000
# 19:15         Carlisle     Native Honey             0.166667
# 19:15         Carlisle    Mayberry Moon             0.285714
# 19:15         Carlisle  Blufferonthebus             0.148148
# 19:15         Carlisle      Jkr Cobbler             0.166667
#
#           Med Fast Races (%)  Low Fast Races (%)  Best Speed (mph)  Best Pos  \
# Off Time
# 13:58               0.500000            0.500000             36.44       1.0
# 13:58               0.000000            0.000000             33.53       2.0
# 13:58               0.111111            0.111111             39.32       2.0
# 13:58               0.111111            0.111111             38.97       1.0
# 13:58               0.000000            0.000000             39.73       3.0
# ...                      ...                 ...               ...       ...
# 19:15               0.200000            0.200000             42.13       1.0
# 19:15               0.166667            0.166667             42.21       1.0
# 19:15               0.285714            0.285714             42.10       1.0
# 19:15               0.185185            0.185185             42.76       1.0
# 19:15               0.166667            0.277778             41.62       1.0
#
#           Mean Pos  Worst Pos   Std Pos  Num Wins  Num Podiums  Num Fast Wins  \
# Off Time
# 13:58     1.500000        2.0  0.707107         1            2              1
# 13:58     2.000000        2.0       NaN         0            1              0
# 13:58     6.555556       13.0  4.447221         0            4              0
# 13:58     3.222222        7.0  1.787301         1            7              0
# 13:58     6.700000       11.0  2.451757         0            1              0
# ...            ...        ...       ...       ...          ...            ...
# 19:15     5.950000       15.0  3.926630         3            6              2
# 19:15     5.583333       10.0  2.874918         1            3              1
# 19:15     5.285714       11.0  3.903600         2            3              2
# 19:15     3.962963       10.0  2.393605         4           13              3
# 19:15     4.722222        9.0  2.803476         3            8              1
#
#           Num Races    Tips
# Off Time
# 13:58             2  8 tips
# 13:58             1   1 tip
# 13:58             9     NaN
# 13:58             9  2 tips
# 13:58            10     NaN
# ...             ...     ...
# 19:15            20     NaN
# 19:15            12  2 tips
# 19:15             7     NaN
# 19:15            27   1 tip
# 19:15            18     NaN
#
# [373 rows x 15 columns]

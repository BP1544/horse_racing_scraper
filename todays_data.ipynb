# %%
from bs4 import BeautifulSoup
from ipynb.fs.full.racing_tv_functions import *

import datetime
import json
import numpy as np
import pandas as pd
import re
import requests
import time

# %%
update_race_data(delay = 0.1)
# Out:
# 'Data is already up to date.'

# %%
today_races = todays_data_df(delay = 0.1)
# Out:
# Collected todays URLs
# Collected race data for Doncaster at 13:15: 1/38
# Collected race data for Doncaster at 13:50: 2/38
# Collected race data for Doncaster at 14:25: 3/38
# Collected race data for Doncaster at 15:00: 4/38
# Collected race data for Doncaster at 15:35: 5/38
# Collected race data for Doncaster at 16:10: 6/38
# Collected race data for Doncaster at 16:43: 7/38
# Collected race data for Doncaster at 17:15: 8/38
# Collected race data for Epsom at 13:37: 9/38
# Collected race data for Epsom at 14:12: 10/38
# Collected race data for Epsom at 14:47: 11/38
# Collected race data for Epsom at 15:18: 12/38
# Collected race data for Epsom at 15:53: 13/38
# Collected race data for Epsom at 16:25: 14/38
# Collected race data for Epsom at 17:00: 15/38
# Collected race data for Clonmel at 15:27: 16/38
# Collected race data for Clonmel at 16:02: 17/38
# Collected race data for Clonmel at 16:37: 18/38
# Collected race data for Clonmel at 17:10: 19/38
# Collected race data for Clonmel at 17:42: 20/38
# Collected race data for Clonmel at 18:15: 21/38
# Collected race data for Clonmel at 18:45: 22/38
# Collected race data for Clonmel at 19:20: 23/38
# Collected race data for Newcastle at 16:55: 24/38
# Collected race data for Newcastle at 17:25: 25/38
# Collected race data for Newcastle at 17:55: 26/38
# Collected race data for Newcastle at 18:25: 27/38
# Collected race data for Newcastle at 18:55: 28/38
# Collected race data for Newcastle at 19:30: 29/38
# Collected race data for Newcastle at 20:00: 30/38
# Collected race data for Newcastle at 20:30: 31/38
# Collected race data for Newcastle at 21:00: 32/38
# Collected race data for Uttoxeter at 16:30: 33/38
# Collected race data for Uttoxeter at 17:05: 34/38
# Collected race data for Uttoxeter at 17:35: 35/38
# Collected race data for Uttoxeter at 18:05: 36/38
# Collected race data for Uttoxeter at 18:35: 37/38
# Collected race data for Uttoxeter at 19:05: 38/38

# %%
horse_df = unpack_json_to_df('historical_horse_data.json')

# %%
cleaned_df = horse_df.dropna(subset=['Position'])
cleaned_df = cleaned_df.replace('N/A', np.nan)
cleaned_df[['Finishing Speed (%)', 'Top Speed Value (mph)']] = cleaned_df[['Finishing Speed (%)', 'Top Speed Value (mph)']].astype(float)

# %%
conditions = {}
id_list = cleaned_df['Race Id'].unique().tolist()
for race_id in id_list:
    conditions.update({race_id : finish_condition(cleaned_df, race_id)})

# %%
high_condition_dict, med_condition_dict, low_condition_dict = ({} for i in range(3))

for race_id in conditions.keys():
    condition_list = conditions[race_id]
    # Update dictionary with {race_id, mean + std}
    high_condition_dict.update({race_id : condition_list[0] + condition_list[1]})
    # Update dictionary with {race_id, mean + 0.8 * std}
    med_condition_dict.update({race_id : condition_list[0] + 0.8 * condition_list[1]})
    # Update dictionary with {race_id, mean + 0.5 * std}
    low_condition_dict.update({race_id : condition_list[0] + 0.5 * condition_list[1]})

# %%
high_fast_list = []
speed_list = cleaned_df['Finishing Speed (%)'].tolist()
id_list = cleaned_df['Race Id'].tolist()

for i in range(len(speed_list)):
    condition = speed_list[i] >= high_condition_dict[id_list[i]]
    if condition:
        high_fast_list.append(True)
    else:
        high_fast_list.append(np.nan)

# %%
med_fast_list = []

for i in range(len(speed_list)):
    condition = speed_list[i] >= med_condition_dict[id_list[i]]
    if condition:
        med_fast_list.append(True)
    else:
        med_fast_list.append(np.nan)

# %%
low_fast_list = []

for i in range(len(speed_list)):
    condition = speed_list[i] >= low_condition_dict[id_list[i]]
    if condition:
        low_fast_list.append(True)
    else:
        low_fast_list.append(np.nan)

# %%
cleaned_df.insert(0, 'Low Fast Finish' , low_fast_list)
cleaned_df.insert(0, 'Med Fast Finish' , med_fast_list)
cleaned_df.insert(0, 'High Fast Finish' , high_fast_list)

# %%
cleaned_df['Fast Finish'] = np.where((cleaned_df['High Fast Finish'] == True) & (cleaned_df['Position'] == 1), True, False)

# %%
grouped_df = cleaned_df.groupby([cleaned_df['Horse']]).agg(
    **{
        # 'Best Finish (%)' : pd.NamedAgg(column = 'Finishing Speed (%)', aggfunc = 'max'),
        # 'Mean Finish (%)' : pd.NamedAgg(column = 'Finishing Speed (%)', aggfunc = 'mean'),
        # 'Worst Finish (%)' : pd.NamedAgg(column = 'Finishing Speed (%)', aggfunc = 'min'),
        # 'Std Finish (%)' : pd.NamedAgg(column = 'Finishing Speed (%)', aggfunc = 'std'),
        # 'Median Finish (%)' : pd.NamedAgg(column = 'Finishing Speed (%)', aggfunc = 'median'),
        'Best Speed (mph)' : pd.NamedAgg(column = 'Top Speed Value (mph)', aggfunc = 'max'),
        'Best Pos' : pd.NamedAgg(column = 'Position', aggfunc = 'min'),
        'Mean Pos' : pd.NamedAgg(column = 'Position', aggfunc = 'mean'),
        'Worst Pos' : pd.NamedAgg(column = 'Position', aggfunc = 'max'),
        'Std Pos' : pd.NamedAgg(column = 'Position', aggfunc = 'std'),
        'High Fast Finishes' : pd.NamedAgg(column = 'High Fast Finish', aggfunc = 'count'),
        'Med Fast Finishes' : pd.NamedAgg(column = 'Med Fast Finish', aggfunc = 'count'),
        'Low Fast Finishes' : pd.NamedAgg(column = 'Low Fast Finish', aggfunc = 'count'),
        'Num Wins' : pd.NamedAgg(column = 'Position', aggfunc = lambda x : (x == 1).sum()),
        'Num Podiums' : pd.NamedAgg(column = 'Position', aggfunc = lambda x : (x <= 3).sum()),
        'Num Fast Wins' : pd.NamedAgg(column = 'Fast Finish', aggfunc = lambda x : (x == True).sum()),
        'Num Races' : pd.NamedAgg(column = 'Position', aggfunc = 'count'), # Number of non-null position values (we have removed all null values)
    }
)

grouped_df['High Fast Races (%)'] = grouped_df['High Fast Finishes'] / grouped_df['Num Races']
grouped_df['Med Fast Races (%)'] = grouped_df['Med Fast Finishes'] / grouped_df['Num Races']
grouped_df['Low Fast Races (%)'] = grouped_df['Low Fast Finishes'] / grouped_df['Num Races']

# %%
grouped_df = grouped_df[['High Fast Races (%)', 'Med Fast Races (%)', 'Low Fast Races (%)', 'Best Speed (mph)',
                         'Best Pos', 'Mean Pos', 'Worst Pos', 'Std Pos', 'High Fast Finishes', 'Med Fast Finishes',
                         'Low Fast Finishes', 'Num Wins', 'Num Podiums', 'Num Fast Wins', 'Num Races']].reset_index()

# %%
today_races = today_races[['Off Time', 'Track', 'Tips']].reset_index()

# Some horse names have different cases on racingtv and racingpost.
# Merging on 'Horse' without case sensitivity.
today_races = pd.merge(
    today_races,
    grouped_df,

    # Used to make merge non case sensitive.
    left_on = today_races['Horse'].str.lower(),
    right_on = grouped_df['Horse'].str.lower(),
                       
    how = 'inner',

    # Used so we can easily remove duplicated 'Horse' column later.
    suffixes = ('', '_y')
)

# Dropping unwanted columns generated during the merge.
today_races = today_races.drop(columns = ['key_0', 'Horse_y']).set_index('Off Time')

today_races = today_races.reset_index().set_index('Off Time')
today_races = today_races[['Track', 'Horse', 'High Fast Races (%)', 'Med Fast Races (%)', 'Low Fast Races (%)',
                           'Best Speed (mph)', 'Best Pos', 'Mean Pos', 'Worst Pos', 'Std Pos', 'Num Wins',
#                           'High Fast Finishes', 'Med Fast Finishes', 'Low Fast Finishes',
                           'Num Podiums', 'Num Fast Wins', 'Num Races', 'Tips']]

# %%
todays_date = pd.Timestamp.today().strftime('%d-%m-%Y')
today_races.round(2).to_csv('./Horse Data/horse_data_{:s}.csv'.format(todays_date))
today_races.round(2).to_csv('./Horse Data/horse_data.csv')

# %%
today_races
# Out:
#               Track             Horse  High Fast Races (%)  \
# Off Time
# 13:15     Doncaster    Half Sovereign             0.500000
# 13:15     Doncaster    Brisk Symphony             0.333333
# 13:15     Doncaster  Rogue Temptation             0.333333
# 13:15     Doncaster       Love Olivia             0.000000
# 13:15     Doncaster         Gwen John             0.666667
# ...             ...               ...                  ...
# 19:05     Uttoxeter       Jungle Wood             0.000000
# 19:05     Uttoxeter        Hammer Dan             0.600000
# 19:05     Uttoxeter    Lord Warburton             0.000000
# 19:05     Uttoxeter       Mind Hunter             0.142857
# 19:05     Uttoxeter       Dakota Beat             0.000000
#
#           Med Fast Races (%)  Low Fast Races (%)  Best Speed (mph)  Best Pos  \
# Off Time
# 13:15               0.500000            0.500000             42.82       1.0
# 13:15               0.666667            0.666667             40.28       1.0
# 13:15               0.333333            0.333333             43.21       1.0
# 13:15               0.000000            0.250000             42.24       1.0
# 13:15               0.666667            0.666667             40.88       1.0
# ...                      ...                 ...               ...       ...
# 19:05               0.000000            0.500000             36.44       1.0
# 19:05               0.600000            0.800000             36.82       1.0
# 19:05               0.071429            0.142857             38.46       1.0
# 19:05               0.142857            0.285714             40.08       2.0
# 19:05               0.000000            0.000000             35.11       4.0
#
#           Mean Pos  Worst Pos   Std Pos  Num Wins  Num Podiums  Num Fast Wins  \
# Off Time
# 13:15     1.750000        4.0  1.500000         3            3              1
# 13:15     2.666667        6.0  2.886751         2            2              1
# 13:15     2.666667        5.0  2.081666         1            2              1
# 13:15     6.000000       13.0  5.291503         1            2              0
# 13:15     1.666667        2.0  0.577350         1            3              0
# ...            ...        ...       ...       ...          ...            ...
# 19:05     2.750000        4.0  1.258306         1            3              0
# 19:05     1.800000        3.0  0.836660         2            5              2
# 19:05     6.857143       14.0  3.939097         2            4              0
# 19:05     7.428571       13.0  4.197505         0            2              0
# 19:05     7.400000        9.0  2.073644         0            0              0
#
#           Num Races    Tips
# Off Time
# 13:15             4  6 tips
# 13:15             3   1 tip
# 13:15             3  2 tips
# 13:15             4     NaN
# 13:15             3  4 tips
# ...             ...     ...
# 19:05             4  3 tips
# 19:05             5  4 tips
# 19:05            14     NaN
# 19:05             7     NaN
# 19:05             5     NaN
#
# [383 rows x 15 columns]
